# %%
import numpy as np
import matplotlib.pyplot as plt
import hdf5storage

# %%
layer_file_path = "/kucresis/scratch/dataproducts/opr_data/rds/2017_Antarctica_BaslerJKB/CSARP_layer/20180110_03/Data_20180110_03_002.mat"

lf = hdf5storage.loadmat(layer_file_path)
lf
